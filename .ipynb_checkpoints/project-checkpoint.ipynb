# %%
import cv2
import numpy as np
import os
from tqdm import tqdm
import mtcnn
from PIL import Image
import pandas as pd
import itertools
import matplotlib.pyplot as plt
import time

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import keras
from keras.models import Sequential,Model
from keras.layers import Dense,Activation,Input
from keras.utils import to_categorical
from keras.layers import Conv2D, MaxPool2D, Flatten

# %%
def cnn_model(input_shape,labels):
    model=Sequential()
    
    model.add(Conv2D(64,(3,3),padding="valid",activation="relu",input_shape=input_shape))
    model.add(Conv2D(64,(3,3),padding="valid",activation="relu",input_shape=input_shape))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(Conv2D(128,(3,3),padding="valid",activation="relu"))
    model.add(Conv2D(128,(3,3),padding="valid",activation="relu"))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(Flatten())
    model.add(Dense(128,activation="relu"))
    model.add(Dense(64,activation="relu"))
    model.add(Dense(len(labels)))
    model.add(Activation("softmax"))
    
    model.summary()
    model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
    
    return model


def Crete_Folder_Images(name, directory, tn):
    # Creating directory in the file
    if not os.path.exists(directory):
        os.makedirs(directory)
    else:
        print('DIRECTORY with name %s EXIST'%name)
    # Opening vedio mode with frontal face detector
    detector=mtcnn.MTCNN()
    cam=cv2.VideoCapture(0)
    size =(100, 100)
    for i in tqdm(range(1, 1+ tn)):
        ret,img=cam.read()
        faces=detector.detect_faces(img)
        for face in faces:
            bounding_box = face['box']
            x=bounding_box[0]
            y=bounding_box[1]
            w=bounding_box[2]
            h=bounding_box[3]
            x1,y1=abs(x),abs(y)
            x2,y2=x1+w,y1+h
            face=img[y1:y2,x1:x2]
            image=Image.fromarray(face)
            image=image.resize(size)
            face_array=np.asarray(image)
            cv2.imwrite('images/'+str(name)+'/'+str(name)+'_'+str(i)+'.jpg', face_array)  #for GRAY SCALE IMAGES

            # cv2.imwrite(directory+'/'+str(name)+'-'+str(sn)+'.jpg'
            #             ,img[y:y+h,x:x+w])  # FOR COLOR IMAGES
            cv2.putText(img,str(i),(25,25),cv2.FONT_HERSHEY_COMPLEX,1,(0,255,0),2)
            cv2.imshow('Sample Collector',img)
            cv2.waitKey(200)
            
    
    cam.release()
    cv2.destroyAllWindows()
    print('TASK COMPLETED')


def print_progress(val,val_len,folder,bar_size=20):
    prog="#"*round((val)*bar_size/val_len)+" "*round((val_len-(val))*bar_size/val_len)
    if val==0:
        print("",end="\n")
    else:
        print("[%s] (%d samples)\t label : %s \t\t" % (prog,val+1,folder), end="\r")
        
def register():
    import mysql.connector  
    name=input("Enter name:")
    i=float(input("Enter id:"))
    g=input("M or F")
    ph=int(input("Enter Phone Number"))
    ''''mydb = mysql.connector.connect(host = "localhost", user = "root",passwd = "Vyshnav@2002",database='fras')  
    mycursor = mydb.cursor()

    sql = "INSERT INTO student VALUES (%s,%s, %s,%s)"
    val = (name,i,ph,g)
    mycursor.execute(sql, val)

    mydb.commit()'''
    
    dir='images/'+name  
    #Crete_Folder_Images(name,dir,5)
    
    dir='download/'
    names=[]
    images=[]
    for folder in os.listdir(dir):
        files=os.listdir(os.path.join(dir,folder))
        for i,name in enumerate(files):
            img=cv2.imread(os.path.join(dir+folder,name))
            cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
            images.append(img)
            names.append(folder)
            print_progress(i,len(files),folder)
    time.sleep(5)
    print("no:of samples :",len(names))
    le=LabelEncoder()
    le.fit(names)
    labels=le.classes_
    name_vec=le.transform(names)
    categorical_name_vec=to_categorical(name_vec)

    x_train,x_test,y_train,y_test=train_test_split(np.array(images,dtype=np.float32),np.array(categorical_name_vec),test_size=0.15,random_state=42)

    input_shape=x_train[0].shape
    EPOCHS=10
    BATCH_SIZE=32

    model=cnn_model(input_shape,labels)
    history=model.fit(x_train,y_train,epochs=EPOCHS,batch_size=BATCH_SIZE,shuffle=True,validation_split=0.15)

# %%
register()
# Out:
# Enter name:rr
# Enter id:3
# M or Fr
# Enter Phone Number44
#
# [####################] (312 samples)	 label : Dhoni
# [####################] (491 samples)	 label : Messi
# [####################] (415 samples)	 label : Ronaldo
# no:of samples : 1660#] (442 samples)	 label : Virat
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_32 (Conv2D)          (None, 98, 98, 64)        1792
#
#  conv2d_33 (Conv2D)          (None, 96, 96, 64)        36928
#
#  max_pooling2d_16 (MaxPoolin  (None, 48, 48, 64)       0
#  g2D)
#
#  conv2d_34 (Conv2D)          (None, 46, 46, 128)       73856
#
#  conv2d_35 (Conv2D)          (None, 44, 44, 128)       147584
#
#  max_pooling2d_17 (MaxPoolin  (None, 22, 22, 128)      0
#  g2D)
#
#  flatten_7 (Flatten)         (None, 61952)             0
#
#  dense_17 (Dense)            (None, 128)               7929984
#
#  dense_18 (Dense)            (None, 64)                8256
#
#  dense_19 (Dense)            (None, 4)                 260
#
#  activation (Activation)     (None, 4)                 0
#
# =================================================================
# Total params: 8,198,660
# Trainable params: 8,198,660
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 38/38 [==============================] - 104s 3s/step - loss: 10.7062 - accuracy: 0.3745 - val_loss: 1.3314 - val_accuracy: 0.4340
# Epoch 2/10
# 38/38 [==============================] - 93s 2s/step - loss: 0.9835 - accuracy: 0.6005 - val_loss: 0.9196 - val_accuracy: 0.6509
# Epoch 3/10
# 38/38 [==============================] - 98s 3s/step - loss: 0.6567 - accuracy: 0.7389 - val_loss: 0.8777 - val_accuracy: 0.7028
# Epoch 4/10
# 38/38 [==============================] - 99s 3s/step - loss: 0.4704 - accuracy: 0.8173 - val_loss: 1.0240 - val_accuracy: 0.7075
# Epoch 5/10
# 38/38 [==============================] - 100s 3s/step - loss: 0.2996 - accuracy: 0.8932 - val_loss: 1.0997 - val_accuracy: 0.7217
# Epoch 6/10
# 38/38 [==============================] - 98s 3s/step - loss: 0.2204 - accuracy: 0.9166 - val_loss: 0.9318 - val_accuracy: 0.7358
# Epoch 7/10
# 38/38 [==============================] - 101s 3s/step - loss: 0.1377 - accuracy: 0.9541 - val_loss: 1.2486 - val_accuracy: 0.7594
# Epoch 8/10
# 38/38 [==============================] - 99s 3s/step - loss: 0.0925 - accuracy: 0.9716 - val_loss: 1.0319 - val_accuracy: 0.7925
# Epoch 9/10
# 38/38 [==============================] - 99s 3s/step - loss: 0.1189 - accuracy: 0.9658 - val_loss: 0.8678 - val_accuracy: 0.7736
# Epoch 10/10
# 38/38 [==============================] - 100s 3s/step - loss: 0.0564 - accuracy: 0.9825 - val_loss: 1.1569 - val_accuracy: 0.7925

# %%
def Crete_Folder_Images(name, directory, tn):
    # Creating directory in the file
    if not os.path.exists(directory):
        os.makedirs(directory)
    else:
        print('DIRECTORY with name %s EXIST'%name)
    # Opening vedio mode with frontal face detector
    detector=mtcnn.MTCNN()
    cam=cv2.VideoCapture(0)
    size =(100, 100)
    for i in tqdm(range(1, 1+ tn)):
        ret,img=cam.read()
        faces=detector.detect_faces(img)
        for face in faces:
            bounding_box = face['box']
            x=bounding_box[0]
            y=bounding_box[1]
            w=bounding_box[2]
            h=bounding_box[3]
            x1,y1=abs(x),abs(y)
            x2,y2=x1+w,y1+h
            face=img[y1:y2,x1:x2]
            image=Image.fromarray(face)
            image=image.resize(size)
            face_array=np.asarray(image)
            cv2.imwrite('images/'+str(name)+'/'+str(name)+'_'+str(i)+'.jpg', face_array)  #for GRAY SCALE IMAGES

            # cv2.imwrite(directory+'/'+str(name)+'-'+str(sn)+'.jpg'
            #             ,img[y:y+h,x:x+w])  # FOR COLOR IMAGES
            cv2.putText(img,str(i),(25,25),cv2.FONT_HERSHEY_COMPLEX,1,(0,255,0),2)
            cv2.imshow('Sample Collector',img)
            cv2.waitKey(200)
            
    
    cam.release()
    cv2.destroyAllWindows()
    print('TASK COMPLETED')

# %%
def print_progress(val,val_len,folder,bar_size=20):
    prog="#"*round((val)*bar_size/val_len)+" "*round((val_len-(val))*bar_size/val_len)
    if val==0:
        print("",end="\n")
    else:
        print("[%s] (%d samples)\t label : %s \t\t" % (prog,val+1,folder), end="\r")

# %%
def cnn_model(input_shape):
    model=Sequential()
    
    model.add(Conv2D(64,(3,3),padding="valid",activation="relu",input_shape=input_shape))
    model.add(Conv2D(64,(3,3),padding="valid",activation="relu",input_shape=input_shape))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(Conv2D(128,(3,3),padding="valid",activation="relu"))
    model.add(Conv2D(128,(3,3),padding="valid",activation="relu"))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(Flatten())
    model.add(Dense(128,activation="relu"))
    model.add(Dense(64,activation="relu"))
    model.add(Dense(len(labels)))
    model.add(Activation("softmax"))
    
    model.summary()
    model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
    
    return model
# Out:
# [################### ] (25 samples)	 label : Midhun
# [################### ] (25 samples)	 label : Vyshnav

# %%
le=LabelEncoder()
le.fit(names)
labels=le.classes_
name_vec=le.transform(names)
categorical_name_vec=to_categorical(name_vec)

# %%
x_train,x_test,y_train,y_test=train_test_split(np.array(images,dtype=np.float32),np.array(categorical_name_vec),test_size=0.15,random_state=42)

# %%
def cnn_model(input_shape):
    model=Sequential()
    
    model.add(Conv2D(64,(3,3),padding="valid",activation="relu",input_shape=input_shape))
    model.add(Conv2D(64,(3,3),padding="valid",activation="relu",input_shape=input_shape))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(Conv2D(128,(3,3),padding="valid",activation="relu"))
    model.add(Conv2D(128,(3,3),padding="valid",activation="relu"))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(Flatten())
    model.add(Dense(128,activation="relu"))
    model.add(Dense(64,activation="relu"))
    model.add(Dense(len(labels)))
    model.add(Activation("softmax"))
    
    model.summary()
    model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
    
    return model

# %%
input_shape=x_train[0].shape
EPOCHS=10
BATCH_SIZE=32

model=cnn_model(input_shape)
history=model.fit(x_train,y_train,epochs=EPOCHS,batch_size=BATCH_SIZE,shuffle=True,validation_split=0.15)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 98, 98, 64)        1792
#
#  conv2d_13 (Conv2D)          (None, 96, 96, 64)        36928
#
#  max_pooling2d_6 (MaxPooling  (None, 48, 48, 64)       0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 46, 46, 128)       73856
#
#  conv2d_15 (Conv2D)          (None, 44, 44, 128)       147584
#
#  max_pooling2d_7 (MaxPooling  (None, 22, 22, 128)      0
#  2D)
#
#  flatten_2 (Flatten)         (None, 61952)             0
#
#  dense_7 (Dense)             (None, 128)               7929984
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  dense_9 (Dense)             (None, 2)                 130
#
#  activation (Activation)     (None, 2)                 0
#
# =================================================================
# Total params: 8,198,530
# Trainable params: 8,198,530
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 5s 809ms/step - loss: 59.2222 - accuracy: 0.4000 - val_loss: 53.8639 - val_accuracy: 0.5714
# Epoch 2/10
# 2/2 [==============================] - 3s 520ms/step - loss: 66.2490 - accuracy: 0.4286 - val_loss: 106.4010 - val_accuracy: 0.4286
# Epoch 3/10
# 2/2 [==============================] - 3s 479ms/step - loss: 72.3204 - accuracy: 0.5714 - val_loss: 17.6140 - val_accuracy: 0.5714
# Epoch 4/10
# 2/2 [==============================] - 3s 481ms/step - loss: 21.1612 - accuracy: 0.4286 - val_loss: 36.6308 - val_accuracy: 0.4286
# Epoch 5/10
# 2/2 [==============================] - 3s 475ms/step - loss: 27.3677 - accuracy: 0.5714 - val_loss: 12.5916 - val_accuracy: 0.4286
# Epoch 6/10
# 2/2 [==============================] - 3s 487ms/step - loss: 8.8615 - accuracy: 0.5714 - val_loss: 3.9054 - val_accuracy: 0.5714
# Epoch 7/10
# 2/2 [==============================] - 3s 478ms/step - loss: 5.1961 - accuracy: 0.4286 - val_loss: 2.4936 - val_accuracy: 0.4286
# Epoch 8/10
# 2/2 [==============================] - 3s 478ms/step - loss: 1.8783 - accuracy: 0.4857 - val_loss: 0.8018 - val_accuracy: 0.4286
# Epoch 9/10
# 2/2 [==============================] - 3s 494ms/step - loss: 0.5064 - accuracy: 0.6000 - val_loss: 0.0145 - val_accuracy: 1.0000
# Epoch 10/10
# 2/2 [==============================] - 3s 466ms/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 1.0000

# %%
def evaluate_model(history):
    names=[['accuracy','val_accuracy'],['loss','val_loss']]
    for name in names:
        fig1,ax_acc=plt.subplots()
        plt.plot(history.history[name[0]])
        plt.plot(history.history[name[1]])
        plt.xlabel('Epoch')
        plt.ylabel(name[0])
        plt.title("model - "+name[0])
        plt.legend(['Training','Validation'],loc='lower right')
        plt.grid()
        plt.show()

evaluate_model(history)

# %%
import mtcnn
size =(100, 100)
detector=mtcnn.MTCNN()
img=cv2.imread('testing/d.jpg')
cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
pixels=np.asarray(img)
faces=detector.detect_faces(img)
for res in faces:            
    bounding_box = res['box']
    x=bounding_box[0]
    y=bounding_box[1]
    w=bounding_box[2]
    h=bounding_box[3]
    x1,y1=abs(x),abs(y)
    x2,y2=x1+w,y1+h
    face=pixels[y1:y2,x1:x2]
    face_img=cv2.resize(face,(100,100))
    face_img=face_img.reshape(1,100,100,3)
# Out:
# 1/1 [==============================] - 0s 288ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 12/12 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 181ms/step

# %%
result=model.predict(face_img)
idx=result.argmax(axis=1)
label_text=labels[idx]
print(label_text)
# Out:
# 1/1 [==============================] - 0s 119ms/step
# ['Vyshnav']

# %%
import mtcnn
size =(100, 100)
detector=mtcnn.MTCNN()
img=cv2.imread('testing/download.jpeg')
cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
faces=detector.detect_faces(img)
for face in faces:            
    x, y, w, h = face['box']
    face_cropped = img[y:y+h, x:x+w]
    face_img=cv2.resize(face_cropped,(100,100))
    face_img=face_img.reshape(1,100,100,3)
    result=model.predict(face_img)
    idx=result.argmax(axis=1)
    label_text=labels[idx]
    print(label_text)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17132\2236471083.py in <module>
#       3 detector=mtcnn.MTCNN()
#       4 img=cv2.imread('testing/download.jpeg')
# ----> 5 cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#       6 faces=detector.detect_faces(img)
#       7 for face in faces:
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
